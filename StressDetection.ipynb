# %% [markdown]
# <a href="https://colab.research.google.com/github/vani2730/VaniPanditML/blob/main/StressDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_subreddit=pd.read_csv("/content/subreddit.csv")
df_subreddit.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df_subreddit.isnull()
# Out:
#       subreddit  post_id  sentence_range   text     id  label  confidence  \
# 0         False    False           False  False  False  False       False
# 1         False    False           False  False  False  False       False
# 2         False    False           False  False  False  False       False
# 3         False    False           False  False  False  False       False
# 4         False    False           False  False  False  False       False
# ...         ...      ...             ...    ...    ...    ...         ...
# 2833      False    False           False  False  False  False       False
# 2834      False    False           False  False  False  False       False
# 2835       True     True            True   True   True   True        True
# 2836      False    False           False  False  False  False       False
# 2837      False    False           False  False  False  False       False
#
#       social_timestamp  social_karma  syntax_ari  ...  Unnamed: 126  \
# ...

# %%
df_subreddit.isnull().sum().sum()
# Out:
# 59875

# %%
import nltk
import re
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english'))

def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
df_subreddit["text"] = df_subreddit["text"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
text = " ".join(i for i in df_subreddit.text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, 
                      background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_subreddit["label"] = df_subreddit["label"].map({0: "No Stress", 1: "Stress"})
data = df_subreddit[["text", "label"]]

# %%
print(df_subreddit.tail())
# Out:
#            subreddit post_id sentence_range  \
# 2833   relationships  7oee1t       [35, 40]
# 2834            ptsd  9p4ung       [20, 25]
# 2835             NaN     NaN            NaN
# 2836  almosthomeless  5y53ya        [5, 10]
# 2837            ptsd  5y25cl         [0, 5]
#
#                                                    text    id label  \
# 2833   week ago precious ignor  jan  happi year prec...  1713   NaN
# 2834  dont abil cope anymor im tri lot thing trigger...  1133   NaN
# 2835                                                nan   NaN   NaN
# 2836  find normal good relationship main problem see...  1834   NaN
# 2837  talk mom morn said sister trauma wors mine did...   961   NaN
#
#        confidence social_timestamp social_karma    syntax_ari  ...  \
# 2833            1       1515187044           13  -1.369333333  ...
# 2834            1       1539827412           33   9.425477855  ...
# 2835          NaN              NaN          NaN           NaN  ...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

x = np.array(data["text"])
y = np.array(data["label"])

cv = CountVectorizer()
X = cv.fit_transform(x)
xtrain, xtest, ytrain, ytest = train_test_split(X, y,
                                                test_size=0.33, 
                                                random_state=42)

# %%
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
model.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ac8df104f92e> in <module>
#       1 from sklearn.naive_bayes import BernoulliNB
#       2 model = BernoulliNB()
# ----> 3 model.fit(xtrain, ytrain)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     661             Returns the instance itself.
#     662         """
# --> 663         X, y = self._check_X_y(X, y)
#     664         _, n_features = X.shape
#     665
#
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y, reset)
#    1151
#    1152     def _check_X_y(self, X, y, reset=True):
# -> 1153         X, y = super()._check_X_y(X, y, reset=reset)
#    1154         if self.binarize is not None:
#    1155             X = binarize(X, threshold=self.binarize)
#
# ...
